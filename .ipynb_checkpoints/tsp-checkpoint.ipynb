# %%
# https://maps.googleapis.com/maps/api/distancematrix/json?key=AIzaSyC-XBt4bk-8CBJAieYIcTXUdzwm8bXeato&mode=bicycling&origins=369%20Orange%20St%20Oakland|469%20Capital%20St%20Oakland|972%2040th%20St%20Oakland|972%20Stanford%20Oakland|1710%20Hearst%20Berkeley|737%2059th%20St%20Oakland|419%2048th%20St%20Oakland&destinations=369%20Orange%20St%20Oakland|469%20Capital%20St%20Oakland|972%2040th%20St%20Oakland|972%20Stanford%20Oakland|1710%20Hearst%20Berkeley|737%2059th%20St%20Oakland|419%2048th%20St%20Oakland

distance_matrix = {
   "destination_addresses" : [
      "369 Orange St, Oakland, CA 94610, USA",
      "469 Capital St, Oakland, CA 94610, USA",
      "972 40th St, Oakland, CA 94608, USA",
      "972 Stanford Ave, Oakland, CA 94608, USA",
      "1710 Hearst Ave, Berkeley, CA 94703, USA",
      "737 59th St, Oakland, CA 94609, USA",
      "419 48th St, Oakland, CA 94609, USA"
   ],
   "origin_addresses" : [
      "369 Orange St, Oakland, CA 94610, USA",
      "469 Capital St, Oakland, CA 94610, USA",
      "972 40th St, Oakland, CA 94608, USA",
      "972 Stanford Ave, Oakland, CA 94608, USA",
      "1710 Hearst Ave, Berkeley, CA 94703, USA",
      "737 59th St, Oakland, CA 94609, USA",
      "419 48th St, Oakland, CA 94609, USA"
   ],
   "rows" : [
      {
         "elements" : [
            {
               "distance" : {
                  "text" : "1 m",
                  "value" : 0
               },
               "duration" : {
                  "text" : "1 min",
                  "value" : 0
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "2.5 km",
                  "value" : 2464
               },
               "duration" : {
                  "text" : "9 mins",
                  "value" : 554
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "4.0 km",
                  "value" : 4048
               },
               "duration" : {
                  "text" : "15 mins",
                  "value" : 872
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.7 km",
                  "value" : 5700
               },
               "duration" : {
                  "text" : "20 mins",
                  "value" : 1222
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "9.1 km",
                  "value" : 9078
               },
               "duration" : {
                  "text" : "36 mins",
                  "value" : 2134
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.1 km",
                  "value" : 5135
               },
               "duration" : {
                  "text" : "19 mins",
                  "value" : 1124
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "3.4 km",
                  "value" : 3416
               },
               "duration" : {
                  "text" : "12 mins",
                  "value" : 748
               },
               "status" : "OK"
            }
         ]
      },
      {
         "elements" : [
            {
               "distance" : {
                  "text" : "2.4 km",
                  "value" : 2375
               },
               "duration" : {
                  "text" : "10 mins",
                  "value" : 597
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1 m",
                  "value" : 0
               },
               "duration" : {
                  "text" : "1 min",
                  "value" : 0
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.6 km",
                  "value" : 5629
               },
               "duration" : {
                  "text" : "20 mins",
                  "value" : 1205
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "7.3 km",
                  "value" : 7281
               },
               "duration" : {
                  "text" : "26 mins",
                  "value" : 1555
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "10.7 km",
                  "value" : 10658
               },
               "duration" : {
                  "text" : "41 mins",
                  "value" : 2467
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "6.7 km",
                  "value" : 6715
               },
               "duration" : {
                  "text" : "24 mins",
                  "value" : 1457
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.0 km",
                  "value" : 4996
               },
               "duration" : {
                  "text" : "18 mins",
                  "value" : 1080
               },
               "status" : "OK"
            }
         ]
      },
      {
         "elements" : [
            {
               "distance" : {
                  "text" : "4.2 km",
                  "value" : 4210
               },
               "duration" : {
                  "text" : "16 mins",
                  "value" : 979
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.8 km",
                  "value" : 5846
               },
               "duration" : {
                  "text" : "21 mins",
                  "value" : 1269
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1 m",
                  "value" : 0
               },
               "duration" : {
                  "text" : "1 min",
                  "value" : 0
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1.7 km",
                  "value" : 1702
               },
               "duration" : {
                  "text" : "6 mins",
                  "value" : 388
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.3 km",
                  "value" : 5331
               },
               "duration" : {
                  "text" : "19 mins",
                  "value" : 1153
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "2.1 km",
                  "value" : 2055
               },
               "duration" : {
                  "text" : "8 mins",
                  "value" : 465
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "2.1 km",
                  "value" : 2095
               },
               "duration" : {
                  "text" : "8 mins",
                  "value" : 482
               },
               "status" : "OK"
            }
         ]
      },
      {
         "elements" : [
            {
               "distance" : {
                  "text" : "5.9 km",
                  "value" : 5907
               },
               "duration" : {
                  "text" : "22 mins",
                  "value" : 1327
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "7.5 km",
                  "value" : 7544
               },
               "duration" : {
                  "text" : "27 mins",
                  "value" : 1617
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "2.2 km",
                  "value" : 2179
               },
               "duration" : {
                  "text" : "8 mins",
                  "value" : 462
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1 m",
                  "value" : 0
               },
               "duration" : {
                  "text" : "1 min",
                  "value" : 0
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "4.4 km",
                  "value" : 4415
               },
               "duration" : {
                  "text" : "16 mins",
                  "value" : 954
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1.2 km",
                  "value" : 1180
               },
               "duration" : {
                  "text" : "6 mins",
                  "value" : 363
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "3.4 km",
                  "value" : 3395
               },
               "duration" : {
                  "text" : "13 mins",
                  "value" : 769
               },
               "status" : "OK"
            }
         ]
      },
      {
         "elements" : [
            {
               "distance" : {
                  "text" : "8.8 km",
                  "value" : 8835
               },
               "duration" : {
                  "text" : "34 mins",
                  "value" : 2044
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "10.7 km",
                  "value" : 10718
               },
               "duration" : {
                  "text" : "37 mins",
                  "value" : 2226
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.4 km",
                  "value" : 5352
               },
               "duration" : {
                  "text" : "18 mins",
                  "value" : 1072
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "3.9 km",
                  "value" : 3911
               },
               "duration" : {
                  "text" : "13 mins",
                  "value" : 766
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1 m",
                  "value" : 0
               },
               "duration" : {
                  "text" : "1 min",
                  "value" : 0
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "4.2 km",
                  "value" : 4208
               },
               "duration" : {
                  "text" : "16 mins",
                  "value" : 940
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.8 km",
                  "value" : 5774
               },
               "duration" : {
                  "text" : "23 mins",
                  "value" : 1382
               },
               "status" : "OK"
            }
         ]
      },
      {
         "elements" : [
            {
               "distance" : {
                  "text" : "5.0 km",
                  "value" : 4950
               },
               "duration" : {
                  "text" : "19 mins",
                  "value" : 1113
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "6.6 km",
                  "value" : 6587
               },
               "duration" : {
                  "text" : "23 mins",
                  "value" : 1403
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "2.1 km",
                  "value" : 2064
               },
               "duration" : {
                  "text" : "8 mins",
                  "value" : 463
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "0.9 km",
                  "value" : 883
               },
               "duration" : {
                  "text" : "4 mins",
                  "value" : 248
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "4.2 km",
                  "value" : 4250
               },
               "duration" : {
                  "text" : "18 mins",
                  "value" : 1064
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1 m",
                  "value" : 0
               },
               "duration" : {
                  "text" : "1 min",
                  "value" : 0
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1.9 km",
                  "value" : 1890
               },
               "duration" : {
                  "text" : "8 mins",
                  "value" : 451
               },
               "status" : "OK"
            }
         ]
      },
      {
         "elements" : [
            {
               "distance" : {
                  "text" : "3.5 km",
                  "value" : 3463
               },
               "duration" : {
                  "text" : "13 mins",
                  "value" : 756
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.1 km",
                  "value" : 5099
               },
               "duration" : {
                  "text" : "17 mins",
                  "value" : 1046
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1.9 km",
                  "value" : 1939
               },
               "duration" : {
                  "text" : "6 mins",
                  "value" : 370
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "3.2 km",
                  "value" : 3235
               },
               "duration" : {
                  "text" : "11 mins",
                  "value" : 663
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "5.8 km",
                  "value" : 5833
               },
               "duration" : {
                  "text" : "24 mins",
                  "value" : 1429
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1.9 km",
                  "value" : 1890
               },
               "duration" : {
                  "text" : "7 mins",
                  "value" : 420
               },
               "status" : "OK"
            },
            {
               "distance" : {
                  "text" : "1 m",
                  "value" : 0
               },
               "duration" : {
                  "text" : "1 min",
                  "value" : 0
               },
               "status" : "OK"
            }
         ]
      }
   ],
   "status" : "OK"
}

# %%
travel_times = [[distance_matrix['rows'][i]['elements'][j]['duration']['value'] for j in range(len(distance_matrix['origin_addresses']))] for i in range(len(distance_matrix['origin_addresses']))]
travel_times
# Out:
# [[0, 554, 872, 1222, 2134, 1124, 748],
#  [597, 0, 1205, 1555, 2467, 1457, 1080],
#  [979, 1269, 0, 388, 1153, 465, 482],
#  [1327, 1617, 462, 0, 954, 363, 769],
#  [2044, 2226, 1072, 766, 0, 940, 1382],
#  [1113, 1403, 463, 248, 1064, 0, 451],
#  [756, 1046, 370, 663, 1429, 420, 0]]

# %%
travel_times[0][1]
# Out:
# 554

# %%
"""Simple travelling salesman problem between cities."""

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp


def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = travel_times
    data['num_vehicles'] = 1
    data['depot'] = 0
    return data


def print_solution(manager, routing, solution):
    """Prints solution on console."""
    print('Objective: {} sec'.format(solution.ObjectiveValue()))
    index = routing.Start(0)
    plan_output = 'Route for vehicle 0:\n'
    route_distance = 0
    while not routing.IsEnd(index):
        plan_output += ' {} ->'.format(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += ' {}\n'.format(manager.IndexToNode(index))
    print(plan_output)
    plan_output += 'Route distance: {}miles\n'.format(route_distance)


def main():
    """Entry point of the program."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(manager, routing, solution)


if __name__ == '__main__':
    main()
# Out:
# Objective: 5248 sec
# Route for vehicle 0:
#  0 -> 2 -> 4 -> 3 -> 5 -> 6 -> 1 -> 0

# %%
369 Orange St
*** 972 40th St
*** 1710 Hearst Ave
972 Stanford Ave
737 59th St
419 48th St
*** 469 Capital St
369 Orange St

1 hr 27 min
14.8 miles

# %%
distance_matrix['origin_addresses']
# Out:
# ['369 Orange St, Oakland, CA 94610, USA',
#  '469 Capital St, Oakland, CA 94610, USA',
#  '972 40th St, Oakland, CA 94608, USA',
#  '972 Stanford Ave, Oakland, CA 94608, USA',
#  '1710 Hearst Ave, Berkeley, CA 94703, USA',
#  '737 59th St, Oakland, CA 94609, USA',
#  '419 48th St, Oakland, CA 94609, USA']
